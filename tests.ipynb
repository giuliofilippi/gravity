# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from birds import *

# %%
star_pos = star_positions()
star_pos_5 = [star_pos[(5*k)%12] for k in range(13)]

# %%
fig,ax = plt.subplots(figsize=(8,8))
plt.scatter([x[0] for x in star_pos], [x[1] for x in star_pos])
x = [pos[0] for pos in star_pos_5]
y = [pos[1] for pos in star_pos_5]
plt.plot(x,y)
#plt.xlim(-1,1)
#plt.ylim(-1,1)

# %%
star_positions()
# Out:
# [array([-0.25881905, -0.96592583]),
#  array([ 0.25881905, -0.96592583]),
#  array([ 0.70710678, -0.70710678]),
#  array([ 0.96592583, -0.25881905]),
#  array([0.96592583, 0.25881905]),
#  array([0.70710678, 0.70710678]),
#  array([0.25881905, 0.96592583]),
#  array([-0.25881905,  0.96592583]),
#  array([-0.70710678,  0.70710678]),
#  array([-0.96592583,  0.25881905]),
#  array([-0.96592583, -0.25881905]),
#  array([-0.70710678, -0.70710678])]

# %% [markdown]
# star_pos

# %%
WHITE = (255,255,255)

# color palette
note_palette = {
    1:WHITE,
    2:WHITE,
    3:WHITE,
    4:WHITE,
    5:WHITE,
    6:WHITE,
    7:WHITE,
    8:WHITE,
    9:WHITE,
    10:WHITE,
    11:WHITE,
    12:WHITE,
}

# %%
new_palette = note_palette.copy()

# %%
new_palette[1]='awrfqrf'

# %%
note_palette
# Out:
# {1: (255, 255, 255),
#  2: (255, 255, 255),
#  3: (255, 255, 255),
#  4: (255, 255, 255),
#  5: (255, 255, 255),
#  6: (255, 255, 255),
#  7: (255, 255, 255),
#  8: (255, 255, 255),
#  9: (255, 255, 255),
#  10: (255, 255, 255),
#  11: (255, 255, 255),
#  12: (255, 255, 255)}

# %%
new_palette = note_palette

# %%
new_palette
# Out:
# {1: (255, 255, 255),
#  2: (255, 255, 255),
#  3: (255, 255, 255),
#  4: (255, 255, 255),
#  5: (255, 255, 255),
#  6: (255, 255, 255),
#  7: (255, 255, 255),
#  8: (255, 255, 255),
#  9: (255, 255, 255),
#  10: (255, 255, 255),
#  11: (255, 255, 255),
#  12: (255, 255, 255)}
